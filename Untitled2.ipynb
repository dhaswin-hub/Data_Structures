# %%
import pandas as pd

# %%
df=pd.read_csv("C:/Users/Ibscai10.DGVC-MCA/iris.csv")
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.isnull().sum()
# Out:
# sepal_length    4
# sepal_width     3
# petal_length    3
# petal_width     4
# class           0
# dtype: int64

# %%
df['sepal_length']=df['sepal_length'].fillna(0)

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     3
# petal_length    3
# petal_width     4
# class           0
# dtype: int64

# %%
mn=df['sepal_width'].mean()
mn
# Out:
# np.float64(3.0380952380952384)

# %%
df['sepal_width']=df['sepal_width'].fillna(mn)

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    3
# petal_width     4
# class           0
# dtype: int64

# %%
mdn=df['petal_length'].median()
mdn
# Out:
# 4.4

# %%
df['petal_length']=df['petal_length'].fillna(mdn)

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     4
# class           0
# dtype: int64

# %%
md=df['petal_width'].mode()[0]
md
# Out:
# np.float64(0.2)

# %%
df['petal_width']=df['petal_width'].fillna(md)

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# class           0
# dtype: int64
